# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Matplotlib is a 2D plotting library for Python that produces high-quality figures and charts. It provides an object-oriented API for embedding plots into applications that use general-purpose GUI toolkits, such as Tkinter, wxPython, Qt, or GTK. Matplotlib is widely used for data visualization and creating static, interactive, and animated plots.
#
# Five plots that can be created using the Pyplot module of Matplotlib:
# 1. Line plot
# 2. Scatter plot
# 3. Bar plot
# 4. Histogram
# 5. Pie chart

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %% [markdown]
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# A scatter plot is a type of data visualization that displays individual data points on a two-dimensional plane. Each point on the plot represents the values of two variables, allowing for the examination of the relationship between them. Scatter plots are particularly useful for identifying patterns, trends, and correlations in the data.

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

# %% [markdown]
# Use the following data:

# %% [markdown]
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# The subplot() function in Matplotlib is used to create a grid of subplots within a single figure. It allows you to organize multiple plots (subplots) in a grid layout, making it easier to compare and analyze different aspects of your data simultaneously. The subplot() function takes three arguments: the number of rows, the number of columns, and the index of the subplot to create

# %%
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2,2,1)
plt.plot(x1,y1)
plt.subplot(2,2,2)
plt.plot(x2,y2)
plt.subplot(2,2,3)
plt.plot(x3,y3)
plt.subplot(2,2,4)
plt.plot(x4,y4)
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# A bar plot is a type of data visualization that uses rectangular bars to represent the values of different categories or groups. The length of each bar corresponds to the quantity or frequency of the data it represents. Bar plots are useful for comparing and visualizing the distribution of categorical data and for highlighting differences or patterns among groups.

# %%
plt.bar(company, profit)
plt.xlabel("Company")
plt.ylabel("Profit")
plt.title("Company V/S Profit (Bar Chart)")
plt.show()

# %%
plt.barh(company, profit)
plt.ylabel("Company")
plt.xlabel("Profit")
plt.title("Company V/S Profit (Bar Chart)")
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# A box plot, also known as a box-and-whisker plot, is a data visualization that provides a summary of the distribution of a dataset. It displays the central tendency, spread, and identifies potential outliers. Box plots are particularly useful for comparing distributions and understanding the variability of the data.

# %%
plt.boxplot(box1)
plt.show()

# %%
plt.boxplot(box2)
plt.show()
